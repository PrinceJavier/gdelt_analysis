# %% [markdown]
# # Exploration of GDELT Dataset

# %% [markdown]
# ## Executive Summary
#
# < Problem statement>
#
# < Introduce dataset>
#
# < Introduce models used>
#
# < Present important results>
#
# < Communicate relevant insights>

# %% [markdown]
# ## Introduction

# %% [markdown]
# < Stated the source of the data and introduced it to provide a complete
# context for understanding the rest of the report>
#
# < Has an explicit and clearly stated problem statement>
#
# < Has an explicit and convincing motivation statement>

# %% [markdown]
# ## Data Collection and Description

# %% [markdown]
# < – Described the data format and provided some relevant metadata that
# allow the reader to clearly understand the data processing code>

# %%
# importing packages
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import dask.dataframe as dd
import dask.bag as db
from dask.delayed import delayed
from dask.distributed import Client
from sklearn.externals.joblib import parallel_backend
from dask.diagnostics import ProgressBar

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# < Performed complete exploratory data analysis that are fully explained>
#
# < All figures are properly labeled and captioned>

# %% [markdown]
# ## Methodology

# %% [markdown]
# < Complete methodology stated, described and justified>

# %% [markdown]
# ## Results

# %% [markdown]
# < results presented are clean, robust and relevant that will allow a strong
# answer or solution to the stated problem>
#
# < explicit answer to the stated problem and presented interesting insights on
# that can be traced back to the methods and discussion results >

# %% [markdown]
# ## References

# %% [markdown]
# http://web.pdx.edu/~kinsella/jgscale.html

# %% [markdown]
# ## Acknowledgements

# %% [markdown]
# ## Test Code

# %%
# set to run Dask commands in this "cluster"
client = Client('10.233.29.219:8786')

# %%
# check the contents of the folder
path = '/mnt/data/public/gdeltv2/*'
glob.glob(path)
# Out:
# ['/mnt/data/public/gdeltv2/20170101190000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170131134500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170210224500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170213203000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170215044500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170225004500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170407133000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170412044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170418044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170427171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170506113000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170511183000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170516070000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170518223000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170528044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170528213000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170602141500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170608121500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170611004500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170712061500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170805174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170809140000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170831190000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170903113000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170912110000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170914023000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170918084500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171005023000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171027181500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171212151500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171215201500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171229061500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180122001500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180202224500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180207003000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180209150000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180212090000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180309124500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180313204500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180402201500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180417071500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180516190000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180604231500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180611020000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180613021500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180617044500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180618233000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180622141500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180703073000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180705003000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180718204500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180808043000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180812010000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180813223000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20150219021500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170203100000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170212023000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170218023000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170321151500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170330084500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170405193000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170415043000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170421230000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170503120000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170504170000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170511034500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170512143000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170520123000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170523013000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170526021500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170601173000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170602043000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170604091500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170608073000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170615180000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170621104500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170625120000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170712014500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170716103000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170730030000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170731214500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170817154500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170825043000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170907143000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170913203000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170927041500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170930160000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170930160000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171001204500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171005163000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171005201500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171007044500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171011231500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171027000000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171109210000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171117114500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171119001500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171127120000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171216040000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171218234500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171220153000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171221133000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171221194500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171221214500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171228193000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180121110000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180125023000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180129151500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180204081500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180211103000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180212011500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180213114500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180217061500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180227043000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180227143000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180228174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180307061500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180307174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180316080000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180316100000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180323113000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180412130000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180416043000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180416101500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180416154500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180427054500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180428010000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180428103000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180503100000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180507063000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180511221500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180524223000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180526033000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180531150000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180606164500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180613121500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180622121500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180623060000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180626184500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180627104500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180709000000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180710030000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180710211500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180722103000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180727131500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180801054500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180813083000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180814184500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180820054500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180820200000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20150219024500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170108074500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170109104500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170114101500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170120180000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170131231500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170201034500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170202183000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170206024500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170213200000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170227121500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170301074500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170304221500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170317103000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170317111500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170321081500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170325023000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170326124500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170405124500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170412083000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170422053000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170511233000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170516201500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170516210000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170520104500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170531233000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170601204500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170613114500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170624211500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170629093000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170701210000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170706140000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170712234500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170719060000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170725213000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170803051500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170813014500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170813070000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170816091500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170823230000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170826100000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170827001500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170827161500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170903213000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170916053000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170927213000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171010044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171014113000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171015003000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171110173000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171112210000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171124023000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171205130000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171206163000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171214193000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171217023000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171224071500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171230080000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180101174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180110173000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180112024500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180130163000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180202044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180203181500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180217103000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180316233000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180318093000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180320054500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180320173000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180321081500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180326011500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180330021500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180330103000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180409100000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180410201500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180411130000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180417171500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180425090000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180503143000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180504140000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180515054500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180519044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180521000000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180524050000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180526091500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180607070000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180706190000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180714084500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180716063000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180722191500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180724220000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180807191500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180809080000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180819203000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20150219064500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170102004500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170102094500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170102104500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170105030000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170107033000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170123121500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170125061500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170217163000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170218003000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170222031500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170227053000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170304070000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170307184500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170308011500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170313181500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170327174500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170407094500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170414004500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170420123000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170427153000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170427184500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170510130000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170605124500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170609111500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170610030000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170612060000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170620070000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170620123000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170624093000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170630194500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170727110000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170816114500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170829110000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170902210000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170905054500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170905110000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170929161500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171016163000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171021180000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171030091500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171103133000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171113194500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171121084500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171121194500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171123034500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171128054500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171128094500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171202020000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171204081500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171205064500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171210011500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171212223000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171218094500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171224060000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180106124500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180107000000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180107041500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180116093000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180122024500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180201014500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180204220000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180214030000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180214163000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180214164500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180215093000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180218064500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180222053000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180225181500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180227114500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180308070000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180309111500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180313150000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180322071500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180324150000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180327074500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180328171500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180403034500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180421131500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180423110000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180506133000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180517174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180608224500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180611024500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180621111500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180621121500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180626153000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180707064500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180712141500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180718091500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180723054500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180728141500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180805000000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180808010000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180815141500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180823040000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180827140000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170101024500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170104103000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170108154500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170112044500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170114063000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170215181500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170217024500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170217101500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170218194500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170304051500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170305173000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170306133000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170309150000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170314113000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170314233000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170318043000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170327074500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170327150000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170401144500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170402043000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170404163000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170408163000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170412064500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170425213000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170502041500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170507151500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170515014500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170519163000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170525103000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170603173000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170604160000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170606124500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170617031500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170620081500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170701134500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170708040000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170710110000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170711184500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170714024500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170802044500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170817113000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170825213000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170924144500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170924190000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171015234500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171102190000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171106203000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171206194500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171212011500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171216154500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171222203000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171225013000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171230133000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180206053000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180206183000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180207013000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180304200000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180311130000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180316050000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180321003000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180330191500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180409151500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180415030000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180503101500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180512081500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180518110000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180524133000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180601121500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180607163000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180611210000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180717070000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180726211500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180727094500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180728154500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180801030000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180820110000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180826150000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20150219043000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170101041500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170103143000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170104003000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170104163000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170114050000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170116091500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170120003000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170121031500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170212021500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170214060000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170305134500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170319134500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170405090000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170405194500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170407110000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170408183000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170414051500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170416171500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170429164500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170501173000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170510184500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170521193000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170526171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170527034500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170529094500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170530000000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170617000000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170619141500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170621040000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170628094500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170702074500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170713204500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170721160000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170722010000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170729033000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170805200000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170814131500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170815220000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170816130000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170822111500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170827164500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170911021500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170916233000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170921080000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170921143000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170923073000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171001110000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171009040000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171011071500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171019001500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171027021500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171031054500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171119104500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171123080000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171125143000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171202223000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171211180000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171215141500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171218044500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171225223000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171226194500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180123184500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180130161500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180131213000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180201071500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180224103000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180304010000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180310043000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180312011500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180319024500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180319073000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180326051500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180329000000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180329074500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180330121500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180403064500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180408163000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180413161500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180422040000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180428063000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180429000000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180501134500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180502204500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180508213000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180517013000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180522184500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180601060000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180601120000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180602190000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180605130000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180610011500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180610091500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180616153000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180624204500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180629224500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180705183000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180706091500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180710164500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180720191500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180721100000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180806090000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180808164500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180815024500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180816024500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170101160000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170103220000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170104084500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170105034500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170116033000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170119104500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170127141500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170128034500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170201081500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170202144500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170205180000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170213221500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170220163000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170220171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170227134500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170301014500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170322171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170327151500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170413124500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170419220000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170422064500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170501144500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170504164500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170510130000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170518103000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170526203000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170526231500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170603211500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170609110000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170611000000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170620064500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170624213000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170630204500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170720123000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170724043000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170730041500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170821220000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170829234500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170830193000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170903093000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170916124500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170921124500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170924183000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170924230000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170928184500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171006034500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171009054500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171011221500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171013091500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171102113000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171105053000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171110013000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171118074500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171123204500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171124154500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171203183000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171228013000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171228080000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171229023000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180121041500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180129204500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180131183000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180206174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180310023000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180314101500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180326124500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180331213000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180418103000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180419034500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180426180000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180430171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180430201500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180501001500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180515063000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180522120000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180522123000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180604174500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180619190000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180711220000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180721171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180722213000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180801100000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180809161500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180812030000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180815091500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180821214500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170101044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170109044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170128194500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170201174500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170209190000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170222020000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170317111500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170320190000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170325074500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170331151500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170401171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170411230000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170516170000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170523134500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170604163000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170608083000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170610063000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170610201500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170624030000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170630224500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170722180000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170802003000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170808041500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170808213000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170818193000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170819211500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170903150000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171024083000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171027194500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171119143000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171119203000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171126053000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171202183000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171204093000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171217001500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171224084500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171227104500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180114121500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180129073000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180129111500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180305211500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180314110000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180321164500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180328130000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180331114500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180403044500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180403104500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180406151500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180408063000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180414213000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180420161500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180510210000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180630054500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180723201500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180726113000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180727013000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180731021500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170101110000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170105020000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170117150000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170213171500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170214051500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170217074500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170217181500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170219163000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170301153000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170305120000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170311131500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170314053000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170322133000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170406073000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170408114500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170408200000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170410181500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170412070000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170516220000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170520143000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170525054500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170529150000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170530214500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170611000000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170618121500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170625071500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170629203000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170712134500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170722043000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170724204500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170727144500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170822004500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170829023000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170831144500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170918160000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170921194500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170922183000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170925151500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171007081500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171018054500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171103190000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171103200000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171123214500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171214120000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171226213000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171229220000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171230194500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180110114500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180128101500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180130014500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180212224500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180223114500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180301083000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180323204500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180401020000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180404094500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180417094500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180429103000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180501113000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180510054500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180524161500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180601223000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180606093000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180609041500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180707091500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180709143000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180716074500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180724070000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180804031500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180804170000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180824131500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180825003000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170101231500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170118111500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170227064500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170306173000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170320033000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170323093000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170330051500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170405063000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170413194500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170419083000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170609231500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170625213000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170715011500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170720051500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170723101500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170820050000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170823173000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170823200000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170824003000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170906234500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170918070000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170918150000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170923221500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171004031500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171019154500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171103163000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171107200000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171107231500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171108094500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171120020000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171220231500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171225054500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171225183000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171226063000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180105140000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180120044500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180122063000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180211093000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180222231500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180314020000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180323124500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180413141500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180416210000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180503183000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180515044500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180516233000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180520161500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180521053000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180604174500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180605174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180607003000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180607080000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180629203000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180711000000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180712003000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180714074500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180723183000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180815010000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180819180000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170102170000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170104131500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170107133000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170205230000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170216221500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170224184500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170303090000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170311173000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170313173000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170330093000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170415233000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170429184500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170430170000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170506040000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170712193000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170713011500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170721233000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170723143000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170731213000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170802121500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170812101500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170812171500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170824073000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170824131500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170907150000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170910204500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171104204500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171204084500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171209020000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171213040000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171215024500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171220233000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171229073000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180102191500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180121151500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180123101500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180125024500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180125154500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180126110000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180217014500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180225234500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180303193000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180316000000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180316034500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180325194500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180328213000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180425154500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180511060000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180513130000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180522103000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180526101500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180601230000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180604011500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180626114500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180706053000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180718140000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180819113000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170102211500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170103031500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170106063000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170111041500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170201061500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170204154500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170208154500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170211210000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170216013000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170224031500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170312103000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170313023000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170321231500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170323123000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170324000000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170329141500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170331040000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170402173000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170404213000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170406174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170411023000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170416090000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170416223000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170507190000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170508124500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170514043000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170520120000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170522181500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170527231500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170531121500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170602043000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170619053000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170706093000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170710040000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170802191500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170806193000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170809114500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170816050000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170821230000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170827103000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170920120000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171004171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171004181500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171005103000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171009061500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171017200000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171018160000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171019133000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171102181500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171120043000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171201210000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171203024500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171209060000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171217180000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171219234500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171225121500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180126231500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180209191500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180221104500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180224153000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180305234500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180310213000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180314143000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180315054500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180315123000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180410111500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180411034500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180415010000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180503170000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180516200000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180519120000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180526010000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180610221500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180613051500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180613103000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180620040000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180626141500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180630183000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180718064500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180725171500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180811224500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180828023000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170101003000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170104203000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170202191500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170209153000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170215174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170217024500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170224121500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170312020000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170417040000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170503013000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170526150000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170531151500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170602093000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170612160000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170625001500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170629113000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170703183000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170715181500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170802153000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170803014500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170803203000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170803213000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170828214500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170910094500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170913034500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170927214500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171005050000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171009090000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171017083000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20171026161500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171103004500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171107023000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20171227101500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180109151500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180226120000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180326031500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180406040000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180406044500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180422040000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180506090000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180507014500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180514033000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180516094500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180520221500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180526120000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180610150000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180711033000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180718230000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180801191500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180804051500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180808194500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180812171500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20180818033000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20180822231500.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170101043000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170101030000.mentions.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170106233000.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170113174500.gkg.csv.zip',
#  '/mnt/data/public/gdeltv2/20170115153000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170115174500.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170122023000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170131143000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170202023000.export.CSV.zip',
#  '/mnt/data/public/gdeltv2/20170217050000.mentions.CSV.zip',
#  ...]

# %%
# we see three kinds of files
# let's open the contents one by one

# we define sample sets
f1 = ['/mnt/data/public/gdeltv2/20170611004500.mentions.CSV.zip']
f2 = ['/mnt/data/public/gdeltv2/20170611004500.export.CSV.zip']
f3 = ['/mnt/data/public/gdeltv2/20170611004500.gkg.csv.zip']

# we import the progress bar
# pbar = ProgressBar()
# pbar.register()

# we load mentions.CSV.zip into a delayed Pandas dataframe

dfs = [delayed(pd.read_csv)(fn, delimiter='\t', header=None,
                            dtype='str', engine='python') for fn in f1]
df = dd.from_delayed(dfs)
print(f1)
display(df.head().T)

# we load export.CSV.zip into a delayed Pandas dataframe

dfs = [delayed(pd.read_csv)(fn, delimiter='\t', header=None,
                            dtype='str', engine='python') for fn in f2]
df = dd.from_delayed(dfs)
print(f2)
display(df.head().T)

# we load gkg.CSV.zip into a delayed Pandas dataframe

dfs = [delayed(pd.read_csv)(fn, delimiter='\t', header=None,
                            dtype='str', engine='python') for fn in f3]
df = dd.from_delayed(dfs)
print(f3)
display(df.head().T)
# Out:
# ['/mnt/data/public/gdeltv2/20170611004500.mentions.CSV.zip']
#                                                     0  \
# 0                                           549285546
# 1                                      20160611023000
# 2                                      20170611004500
# 3                                                   1
# 4                                         nbcnews.com
# 5   http://www.nbcnews.com/news/us-news/jeff-sessi...
# 6                                                  28
# 7                                                  -1
# 8                                                5102
# 9                                                5060
# 10                                                  0
# 11                                                 20
# 12                                               5593
# 13                                  -0.32085561497326
# 14                                                nan
# 15                                                nan
#
#                                                     1  \
# 0                                           549255686
# 1                                      20160611001500
# 2                                      20170611004500
# 3                                                   1
# 4                                         nbcnews.com
# 5   http://www.nbcnews.com/news/us-news/jeff-sessi...
# 6                                                  28
# 7                                                  -1
# 8                                                5102
# 9                                                5060
# 10                                                  1
# 11                                                 80
# 12                                               5593
# 13                                  -0.32085561497326
# 14                                                nan
# 15                                                nan
#
#                                                     2  \
# 0                                           549316095
# 1                                      20160611053000
# 2                                      20170611004500
# 3                                                   1
# 4                                            cbs8.com
# 5   http://www.cbs8.com/story/35635737/london-brid...
# 6                                                   6
# 7                                                1174
# 8                                                  -1
# 9                                                1122
# 10                                                  1
# 11                                                100
# 12                                               4821
# 13                                  -7.60998810939357
# 14                                                nan
# 15                                                nan
#
#                                                     3  \
# 0                                           549316095
# 1                                      20160611053000
# 2                                      20170611004500
# 3                                                   1
# 4                                          kaaltv.com
# 5   http://www.KAALtv.com/world/london-bridge-atta...
# 6                                                   6
# 7                                                1149
# 8                                                  -1
# 9                                                1097
# 10                                                  1
# 11                                                100
# 12                                               5118
# 13                                           -7.03125
# 14                                                nan
# 15                                                nan
#
#                                                     4
# 0                                           663766551
# 1                                      20170611004500
# 2                                      20170611004500
# 3                                                   1
# 4                                         nbcnews.com
# 5   http://www.nbcnews.com/storyline/isis-uncovere...
# 6                                                  10
# 7                                                2894
# 8                                                2922
# 9                                                2909
# 10                                                  1
# 11                                                 80
# 12                                               4864
# 13                                  -4.30107526881721
# 14                                                nan
# 15                                                nan
# ['/mnt/data/public/gdeltv2/20170611004500.export.CSV.zip']
#                                                     0  \
# 0                                           663766551
# 1                                            20160611
# 2                                              201606
# 3                                                2016
# 4                                           2016.4411
# 5                                                 REB
# 6                                      SUICIDE BOMBER
# 7                                                 nan
# 8                                                 nan
# 9                                                 nan
# 10                                                nan
# 11                                                nan
# 12                                                REB
# 13                                                nan
# 14                                                nan
# 15                                                JOR
# 16                                          JORDANIAN
# 17                                                JOR
# 18                                                nan
# 19                                                nan
# 20                                                nan
# 21                                                nan
# 22                                                nan
# 23                                                nan
# 24                                                nan
# 25                                                  0
# 26                                               1831
# 27                                                183
# 28                                                 18
# 29                                                  4
# ..                                                ...
# 31                                                  8
# 32                                                  1
# 33                                                  8
# 34                                  -4.30107526881721
# 35                                                  1
# 36                                             Jordan
# 37                                                 JO
# 38                                                 JO
# 39                                                nan
# 40                                                 31
# 41                                                 36
# 42                                                 JO
# 43                                                  1
# 44                                             Jordan
# 45                                                 JO
# 46                                                 JO
# 47                                                nan
# 48                                                 31
# 49                                                 36
# 50                                                 JO
# 51                                                  1
# 52                                             Jordan
# 53                                                 JO
# 54                                                 JO
# 55                                                nan
# 56                                                 31
# 57                                                 36
# 58                                                 JO
# 59                                     20170611004500
# 60  http://www.nbcnews.com/storyline/isis-uncovere...
#
#                                                     1  \
# 0                                           663766552
# 1                                            20160611
# 2                                              201606
# 3                                                2016
# 4                                           2016.4411
# 5                                                 USA
# 6                                       UNITED STATES
# 7                                                 USA
# 8                                                 nan
# 9                                                 nan
# 10                                                nan
# 11                                                nan
# 12                                                nan
# 13                                                nan
# 14                                                nan
# 15                                                nan
# 16                                                nan
# 17                                                nan
# 18                                                nan
# 19                                                nan
# 20                                                nan
# 21                                                nan
# 22                                                nan
# 23                                                nan
# 24                                                nan
# 25                                                  0
# 26                                                081
# 27                                                081
# 28                                                 08
# 29                                                  2
# ..                                                ...
# 31                                                  4
# 32                                                  1
# 33                                                  4
# 34                                  -0.96818810511757
# 35                                                  3
# 36                 Shandon, California, United States
# 37                                                 US
# 38                                               USCA
# 39                                              CA079
# 40                                            35.6552
# 41                                           -120.375
# 42                                             249342
# 43                                                  0
# 44                                                nan
# 45                                                nan
# 46                                                nan
# 47                                                nan
# 48                                                nan
# 49                                                nan
# 50                                                nan
# 51                                                  3
# 52                 Shandon, California, United States
# 53                                                 US
# 54                                               USCA
# 55                                              CA079
# 56                                            35.6552
# 57                                           -120.375
# 58                                             249342
# 59                                     20170611004500
# 60  http://www.sanluisobispo.com/news/local/articl...
#
#                                                     2  \
# 0                                           663766553
# 1                                            20160611
# 2                                              201606
# 3                                                2016
# 4                                           2016.4411
# 5                                                 USA
# 6                                              THE US
# 7                                                 USA
# 8                                                 nan
# 9                                                 nan
# 10                                                nan
# 11                                                nan
# 12                                                nan
# 13                                                nan
# 14                                                nan
# 15                                                nan
# 16                                                nan
# 17                                                nan
# 18                                                nan
# 19                                                nan
# 20                                                nan
# 21                                                nan
# 22                                                nan
# 23                                                nan
# 24                                                nan
# 25                                                  0
# 26                                                120
# 27                                                120
# 28                                                 12
# 29                                                  3
# ..                                                ...
# 31                                                  2
# 32                                                  1
# 33                                                  2
# 34                                  -2.01117318435755
# 35                                                  1
# 36                                             Sweden
# 37                                                 SW
# 38                                                 SW
# 39                                                nan
# 40                                                 62
# 41                                                 15
# 42                                                 SW
# 43                                                  0
# 44                                                nan
# 45                                                nan
# 46                                                nan
# 47                                                nan
# 48                                                nan
# 49                                                nan
# 50                                                nan
# 51                                                  1
# 52                                             Sweden
# 53                                                 SW
# 54                                                 SW
# 55                                                nan
# 56                                                 62
# 57                                                 15
# 58                                                 SW
# 59                                     20170611004500
# 60  http://www.theage.com.au/world/sweden-figured-...
#
#                                                     3  \
# 0                                           663766554
# 1                                            20160611
# 2                                              201606
# 3                                                2016
# 4                                           2016.4411
# 5                                                 USA
# 6                                       UNITED STATES
# 7                                                 USA
# 8                                                 nan
# 9                                                 nan
# 10                                                nan
# 11                                                nan
# 12                                                nan
# 13                                                nan
# 14                                                nan
# 15                                                RUS
# 16                                            RUSSIAN
# 17                                                RUS
# 18                                                nan
# 19                                                nan
# 20                                                nan
# 21                                                nan
# 22                                                nan
# 23                                                nan
# 24                                                nan
# 25                                                  1
# 26                                                040
# 27                                                040
# 28                                                 04
# 29                                                  1
# ..                                                ...
# 31                                                  4
# 32                                                  2
# 33                                                  4
# 34                                   1.98251672782214
# 35                                                  3
# 36    Washington, District of Columbia, United States
# 37                                                 US
# 38                                               USDC
# 39                                              DC001
# 40                                            38.8951
# 41                                           -77.0364
# 42                                             531871
# 43                                                  3
# 44    Washington, District of Columbia, United States
# 45                                                 US
# 46                                               USDC
# 47                                              DC001
# 48                                            38.8951
# 49                                           -77.0364
# 50                                             531871
# 51                                                  3
# 52    Washington, District of Columbia, United States
# 53                                                 US
# 54                                               USDC
# 55                                              DC001
# 56                                            38.8951
# 57                                           -77.0364
# 58                                             531871
# 59                                     20170611004500
# 60  http://www.air1.com/news/2017/06/10/Jeff-Sessi...
#
#                                                     4
# 0                                           663766555
# 1                                            20160611
# 2                                              201606
# 3                                                2016
# 4                                           2016.4411
# 5                                                 USA
# 6                                       UNITED STATES
# 7                                                 USA
# 8                                                 nan
# 9                                                 nan
# 10                                                nan
# 11                                                nan
# 12                                                nan
# 13                                                nan
# 14                                                nan
# 15                                                RUS
# 16                                            RUSSIAN
# 17                                                RUS
# 18                                                nan
# 19                                                nan
# 20                                                nan
# 21                                                nan
# 22                                                nan
# 23                                                nan
# 24                                                nan
# 25                                                  1
# 26                                                040
# 27                                                040
# 28                                                 04
# 29                                                  1
# ..                                                ...
# 31                                                  2
# 32                                                  1
# 33                                                  2
# 34                                   1.76991150442478
# 35                                                  3
# 36    Washington, District of Columbia, United States
# 37                                                 US
# 38                                               USDC
# 39                                              DC001
# 40                                            38.8951
# 41                                           -77.0364
# 42                                             531871
# 43                                                  1
# 44                                             Russia
# 45                                                 RS
# 46                                                 RS
# 47                                                nan
# 48                                                 60
# 49                                                100
# 50                                                 RS
# 51                                                  1
# 52                                             Russia
# 53                                                 RS
# 54                                                 RS
# 55                                                nan
# 56                                                 60
# 57                                                100
# 58                                                 RS
# 59                                     20170611004500
# 60  http://www.air1.com/news/2017/06/10/Jeff-Sessi...
#
# [61 rows x 5 columns]
# ['/mnt/data/public/gdeltv2/20170611004500.gkg.csv.zip']
#                                                     0  \
# 0                                    20170611004500-0
# 1                                      20170611004500
# 2                                                   1
# 3                                  dailyexcelsior.com
# 4   http://www.dailyexcelsior.com/ddc-kupwara-insp...
# 5                                                 nan
# 6                                                 nan
# 7   GENERAL_HEALTH;MEDICAL;SOC_POINTSOFINTEREST;SO...
# 8   ECON_STOCKMARKET,1471;TAX_FNCACT_PARAMEDICS,60...
# 9   4#Kupwara, Jammu And Kashmir, India#IN#IN12#34...
# 10  4#Kupwara, Jammu And Kashmir, India#IN#IN12#72...
# 11                                                nan
# 12                                                nan
# 13                                  health department
# 14        Health Department,741;Health Department,965
# 15  0.881057268722467,3.52422907488987,2.643171806...
# 16                                        4#6#10#0#10
# 17  wc:207,c1.3:2,c12.1:9,c12.10:16,c12.12:7,c12.1...
# 18                                                nan
# 19                                                nan
# 20                                                nan
# 21  https://youtube.com/channel/UCT4ZAqOV3-2s5pKnB...
# 22                                                nan
# 23  Khalid Jahangir,42;District Hospital Kupwara,1...
# 24                                                nan
# 25                                                nan
# 26  <PAGE_LINKS>http://www.dailyexcelsior.com/cate...
#
#                                                     1  \
# 0                                    20170611004500-1
# 1                                      20170611004500
# 2                                                   1
# 3                              thebusinessjournal.com
# 4   http://www.thebusinessjournal.com/news/constru...
# 5                                                 nan
# 6                                                 nan
# 7   MANMADE_DISASTER_IMPLIED;TAX_FNCACT;TAX_FNCACT...
# 8   TAX_FNCACT_BUILDER,675;ECON_HOUSING_PRICES,533...
# 9   2#California, United States#US#USCA#36.17#-119...
# 10  3#Fresno, California, United States#US#USCA#CA...
# 11  harry armstrong;brent mccaffrey;gary l mcdonal...
# 12  Harry Armstrong,1308;Brent Mccaffrey,584;Jim P...
# 13  building industry association of fresno madera...
# 14  California Homebuilding Foundation Hall,865;Am...
# 15  3.16205533596838,3.95256916996047,0.7905138339...
# 16                                        4#4#28#0#90
# 17  wc:241,c1.2:3,c12.1:11,c12.10:10,c12.12:3,c12....
# 18  http://www.thebusinessjournal.com/images/stori...
# 19                                                nan
# 20                                                nan
# 21                                                nan
# 22                                                nan
# 23  Business Journal,140;Central Valley,408;Assemb...
# 24  40,under 40 rising stars,506;40,rising stars,5...
# 25                                                nan
# 26                                                nan
#
#                                                     2  \
# 0                                    20170611004500-2
# 1                                      20170611004500
# 2                                                   1
# 3                                     therepublic.com
# 4   http://www.therepublic.com/2017/06/10/us-comey...
# 5                                                 nan
# 6                                                 nan
# 7   TAX_FNCACT;TAX_FNCACT_DIRECTOR;LEADER;TAX_FNCA...
# 8   TAX_FNCACT_DEPUTY,4410;TAX_POLITICAL_PARTY_REP...
# 9   2#New York, United States#US#USNY#42.1497#-74....
# 10  3#Capitol Hill, District Of Columbia, United S...
# 11  evan barr;donald trump;ben wittes;eric holder;...
# 12  Evan Barr,1439;Donald Trump,274;Ben Wittes,629...
# 13  college of william mary;university of chicago;...
# 14  College Of William Mary,3855;University Of Chi...
# 15  -0.0917431192660549,2.84403669724771,2.9357798...
# 16       1#0#0#2003#4282;1#0#0#2013#4561;4#5#9#0#5136
# 17  wc:1021,c12.1:85,c12.10:111,c12.12:38,c12.13:3...
# 18  http://d1bdhkmqqz901h.cloudfront.net/1200x630/...
# 19                                                nan
# 20                                                nan
# 21                                                nan
# 22                                                nan
# 23  President Donald,252;Capitol Hill,306;Hillary ...
# 24  7,months ago may now,2816;2,spot at the Justic...
# 25                                                nan
# 26  <PAGE_AUTHORS>The Associated Press</PAGE_AUTHO...
#
#                                                     3  \
# 0                                    20170611004500-3
# 1                                      20170611004500
# 2                                                   1
# 3                                     echonews.com.au
# 4   https://www.echonews.com.au/news/going-electri...
# 5                                                 nan
# 6                                                 nan
# 7                           MANMADE_DISASTER_IMPLIED;
# 8   MANMADE_DISASTER_IMPLIED,224;MANMADE_DISASTER_...
# 9   4#Ewingsdale, New South Wales, Australia#AS#AS...
# 10  4#Ewingsdale, New South Wales, Australia#AS#AS...
# 11                      harman kardon;richard hammond
# 12            Harman Kardon,1041;Richard Hammond,4401
# 13                                     bmw;rush court
# 14  Bmw,147;Bmw,378;Bmw,1160;Bmw,2344;Bmw,3719;Rus...
# 15  2.2417934347478,4.72377902321858,2.48198558847...
# 16                                    1#0#0#2000#1257
# 17  wc:1110,c1.1:3,c1.2:1,c1.3:3,c12.1:76,c12.10:1...
# 18  https://media.apnarm.net.au/media/images/2017/...
# 19  https://media.apnarm.net.au/media/images/2017/...
# 20                                                nan
# 21                                                nan
# 22  4651|52||What can you put inside Sad Kanye to ...
# 23  Down Under,401;Harman Kardon,1121;Apple CarPla...
# 24  4,plug,176;108,dollars ,385;3,litres for every...
# 25                                                nan
# 26  <PAGE_LINKS>https://www.echonews.com.au/classi...
#
#                                                     4
# 0                                    20170611004500-4
# 1                                      20170611004500
# 2                                                   1
# 3                                  borderwatch.com.au
# 4   http://www.borderwatch.com.au/story/4721481/pe...
# 5                                                 nan
# 6                                                 nan
# 7                                                 nan
# 8                                                 nan
# 9   4#Penrith, New South Wales, Australia#AS#AS02#...
# 10  4#Carrington Park, New South Wales, Australia#...
# 11  joey leilua;bradley jurd bradleyjurd;nathan cl...
# 12  Joey Leilua,2882;Bradley Jurd Bradleyjurd,1188...
# 13                                                nan
# 14                                                nan
# 15  -1.3986013986014,2.44755244755245,3.8461538461...
# 16                                      4#6#24#0#3235
# 17  wc:534,c12.1:58,c12.10:59,c12.12:21,c12.13:17,...
# 18  http://nnimgt-a.akamaihd.net/transform/v1/crop...
# 19                                                nan
# 20                 http://pic.twitter.com/Ge7Pbk2s20;
# 21                                                nan
# 22            1633|30||great achievement for the boys
# 23  Penrith Panthers,24;Wellington Cowboys,138;Tyr...
# 24  8,points going into the,239;6,tackles left,597...
# 25                                                nan
# 26  <PAGE_LINKS>https://t.co/Ge7Pbk2s20;https://tw...

# %%
# We see that there are no columns in the dataset
# We found the columns in GDELT website

events_columns = ['GlobalEventID', 'Day', 'MonthYear', 'Year', 'FractionDate',
                  'Actor1Code', 'Actor1Name', 'Actor1CountryCode',
                  'Actor1KnownGroupCode', 'Actor1EthnicCode',
                  'Actor1Religion1Code', 'Actor1Religion2Code',
                  'Actor1Type1Code', 'Actor1Type2Code', 'Actor1Type3Code',
                  'Actor2Code', 'Actor2Name', 'Actor2CountryCode',
                  'Actor2KnownGroupCode', 'Actor2EthnicCode',
                  'Actor2Religion1Code', 'Actor2Religion2Code',
                  'Actor2Type1Code', 'Actor2Type2Code', 'Actor2Type3Code',
                  'IsRootEvent', 'EventCode', 'EventBaseCode',
                  'EventRootCode', 'QuadClass', 'GoldsteinScale',
                  'NumMentions', 'NumSources', 'NumArticles', 'AvgTone',
                  'Actor1Geo_Type', 'Actor1Geo_Fullname',
                  'Actor1Geo_CountryCode', 'Actor1Geo_ADM1Code',
                  'Actor1Geo_ADM2Code', 'Actor1Geo_Lat', 'Actor1Geo_Long',
                  'Actor1Geo_FeatureID', 'Actor2Geo_Type',
                  'Actor2Geo_Fullname', 'Actor2Geo_CountryCode',
                  'Actor2Geo_ADM1Code', 'Actor2Geo_ADM2Code',
                  'Actor2Geo_Lat', 'Actor2Geo_Long', 'Actor2Geo_FeatureID',
                  'ActionGeo_Type', 'ActionGeo_Fullname',
                  'ActionGeo_CountryCode', 'ActionGeo_ADM1Code',
                  'ActionGeo_ADM2Code', 'ActionGeo_Lat', 'ActionGeo_Long',
                  'ActionGeo_FeatureID', 'DATEADDED', 'SOURCEURL']
gkg_columns = ['GKGRECORDID', 'V2.1DATE', 'V2SOURCECOLLECTIONIDENTIFIER', 'V2SOURCECOMMONNAME',
               'V2DOCUMENTIDENTIFIER', 'V1COUNTS', 'V2.1COUNTS', 'V1THEMES', 'V2ENHANCEDTHEMES',
               'V1LOCATIONS', 'V2ENHANCEDLOCATIONS', 'V1PERSONS', 'V2ENHANCEDPERSONS',
               'V1ORGANIZATIONS', 'V2ENHANCEDORGANIZATIONS', 'V1.5TONE', 'V2.1ENHANCEDDATES',
               'V2GCAM', 'V2.1SHARINGIMAGE', 'V2.1RELATEDIMAGES', 'V2.1SOCIALIMAGEEMBEDS',
               'V2.1SOCIALVIDEOEMBEDS', 'V2.1QUOTATIONS', 'V2.1ALLNAMES', 'V2.1AMOUNTS',
               'V2.1TRANSLATIONINFO', 'V2EXTRASXML']

# %%
# We are ready to load a larger dataset

# we import the progress bar
pbar = ProgressBar()
pbar.register()

# we define an events dataframe cleaner and loader


def load_events(filenames):
    '''
    Load events data from list of filenames
    Select necessary columns, drop null values
    Convert numerical values to float
    Return the cleaned dask dataframe
    '''
    f_events = filenames
    # we load export.CSV.zip into a delayed Pandas dataframe
    dfs_events = [delayed(pd.read_csv)(fn, delimiter='\t', header=None,
                                       dtype='str', names=events_columns, engine='python') for fn in f_events]
    df_events = dd.from_delayed(dfs_events).set_index('GlobalEventID')

    # Convert numerical datapoints to floats
    to_conv = ['Day', 'GoldsteinScale', 'NumMentions',
               'NumSources', 'NumArticles', 'AvgTone', 'Actor1Geo_Lat', 'Actor1Geo_Long']
    df_events[to_conv] = df_events[to_conv].astype(float)
    print("> Converted numerical data to float.")

    # Check average goldstein score, avgTone of each country/location
    # Columns to keep
    keep_cols = ['Day', 'GoldsteinScale', 'NumMentions',
                 'NumSources', 'NumArticles', 'AvgTone', 'Actor1Geo_Lat', 'Actor1Geo_Long',
                 'Actor1Geo_CountryCode', 'Actor1Geo_Fullname']

    # Extract the needed data
    df_ = df_events[keep_cols]
    print("> Selected needed data from Events data.")
    print(f"> Type of dataframe {type(df_)}")

    # Drop null values
    df_ = df_.dropna(
        subset=['GoldsteinScale', 'NumMentions', 'AvgTone', 'Actor1Geo_Lat', 'Actor1Geo_Long', 'Actor1Geo_CountryCode', 'Actor1Geo_Fullname'])
    print("> Null values dropped.")

    return df_

# %%
# load January 2017
f_events = glob.glob('/mnt/data/public/gdeltv2/201801*.export.CSV.zip')
df_ = load_events(f_events)
# Out:
# > Converted numerical data to float.
# > Selected needed data from Events data.
# > Type of dataframe <class 'dask.dataframe.core.DataFrame'>
# > Null values dropped.

# %%
# Interesting data to examine in Events dataset
    # Goldstein score of each country == general stability of the region
    # NumMentions = number of mentions of the event over 15 minutes; importance
    # NumSources = number of sources of event; importance
    # NumArticles =  number of articles of event; importance
    # AvgTone = how positive or how negative the event is
    
    # To be continued

# %%
# Get a sample for plotting 
frac = 0.1
df_events_sample = df_.sample(frac=frac).persist()
print(f"> Obtained a {frac} sample for plotting.")
print("> Selected data persisted into workers.")
# Out:
# > Obtained a 0.1 sample for plotting.
# > Selected data persisted into workers.

# %%
# Plot the longitudes and latitudes color coded according to Goldstein value

# Persist first
y = df_events_sample['Actor1Geo_Lat'].to_dask_array(lengths=True).compute()
x = df_events_sample['Actor1Geo_Long'].to_dask_array(lengths=True).compute()
goldstein = df_events_sample['GoldsteinScale'].to_dask_array(lengths=True).compute()
avgtone = df_events_sample['AvgTone'].to_dask_array(lengths=True).compute()
num_mentions = df_events_sample['NumMentions'].to_dask_array(lengths=True).compute()
print("> Coordinates and other valuable data to be visualized computed successfully.")
# Out:
# > Coordinates and other valuable data to be visualized computed successfully.

# %%
# Goldstein values vs Latitude and Longitude
# Color is goldstein while size is importance (num_mentions)
plt.style.use('default')
f, ax = plt.subplots(figsize=(11,5))
ax.scatter(x, y, c=goldstein, marker='o', s=num_mentions/3, cmap='Spectral', alpha=0.75)
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.axis('equal')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Goldstein score per event')
plt.tight_layout()

# Save figure
plt.savefig("charts/goldstein_world.png", dpi=150)

# %%
# AvgTone values vs Latitude and Longitude
# Color is avg tone while size is importance (num_mentions)
f, ax = plt.subplots(figsize=(11,5))
ax.scatter(x, y, c=avgtone, marker='o', s=num_mentions/3, cmap='Spectral', alpha=0.75)
plt.axis('equal')
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Average Tone per event')
plt.tight_layout()

# Save figure
plt.savefig("charts/avgtone_world.png", dpi=150)

# %%
# Goldstein and Avg Tone Score bar charts

# Average Goldstein score pe country weighted by number of mentions (importance)
# New column added containing the weighted GoldsteinScale
df_['weighted_goldstein'] = df_['GoldsteinScale']*df_['NumMentions']
df_['weighted_avgtone'] = df_['AvgTone']*df_['NumMentions']
print("> New weighted Goldstein Scale column created.")
print("> New weighted avgtone column created.")

# group by Actor1Geo_CountryCode and get GoldsteinScale
df_by_country = df_.groupby(by='Actor1Geo_CountryCode').mean().compute()
print("> Data grouped by Actor1Geo_CountryCode and persisted successfully.")
# Out:
# > New weighted Goldstein Scale column created.
# > New weighted avgtone column created.
# > Data grouped by Actor1Geo_Fullname and persisted successfully.

# %%
df_by_country.head()
# Out:
#                        Actor1Geo_Fullname  Actor1Geo_Lat  Actor1Geo_Long  \
# Actor1Geo_CountryCode
# AE                                    NaN      24.958641       54.973415
# AF                                    NaN      33.915178       67.660977
# AG                                    NaN      32.055035        3.219868
# AJ                                    NaN      40.392772       48.300781
# AO                                    NaN     -11.036743       16.369391
#
#                         AvgTone           Day  GoldsteinScale  NumArticles  \
# Actor1Geo_CountryCode
# AE                     0.058877  2.017979e+07        1.525427     4.752746
# AF                    -4.278423  2.017984e+07       -1.129177     4.718244
# AG                    -2.546162  2.017992e+07        0.533276     4.849675
# AJ                    -1.321937  2.017998e+07        1.188847     5.075959
# AO                    -0.880446  2.017991e+07        1.542678     4.725059
#
#                        NumMentions  NumSources  weighted_avgtone  \
# Actor1Geo_CountryCode
# AE                        4.817878    1.053802         -0.361975
# AF                        4.968279    1.086981        -22.137284
# AG                        4.991459    1.041339        -12.692856
# AJ                        5.281674    1.083977         -7.817205
# AO                        4.845451    1.019953         -4.889895
#
#                        weighted_goldstein
# Actor1Geo_CountryCode
# AE                               6.989921
# AF                              -6.628386
# AG                               1.902665
# AJ                               6.133197
# AO                               7.988536

# %%
# Get the mean
# world = df_[['GoldsteinScale', 'AvgTone', 'weighted_avgtone', 'weighted_goldstein']].mean().compute()
world = np.mean(df_['GoldsteinScale'].values).compute()
print("> loaded global value")
world.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-05e22bc69c14> in <module>()
#       1 # Get the mean
#       2 # world = df_[['GoldsteinScale', 'AvgTone', 'weighted_avgtone', 'weighted_goldstein']].mean().compute()
# ----> 3 world = np.mean(df_['GoldsteinScale'].values).compute()
#       4 print("> loaded global value")
#       5 world.head()
#
# /opt/conda/lib/python3.6/site-packages/dask/base.py in compute(self, **kwargs)
#     154         dask.base.compute
#     155         """
# --> 156         (result,) = compute(self, traverse=False, **kwargs)
#     157         return result
#     158
#
# /opt/conda/lib/python3.6/site-packages/dask/base.py in compute(*args, **kwargs)
#     393     keys = [x.__dask_keys__() for x in collections]
#     394     postcomputes = [x.__dask_postcompute__() for x in collections]
# --> 395     results = schedule(dsk, keys, **kwargs)
#     396     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     397
#
# /opt/conda/lib/python3.6/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, **kwargs)
#    2216             try:
#    2217                 results = self.gather(packed, asynchronous=asynchronous,
# -> 2218                                       direct=direct)
#    2219             finally:
#    2220                 for f in futures.values():
#
# /opt/conda/lib/python3.6/site-packages/distributed/client.py in gather(self, futures, errors, maxsize, direct, asynchronous)
#    1579             return self.sync(self._gather, futures, errors=errors,
#    1580                              direct=direct, local_worker=local_worker,
# -> 1581                              asynchronous=asynchronous)
#    1582
#    1583     @gen.coroutine
#
# /opt/conda/lib/python3.6/site-packages/distributed/client.py in sync(self, func, *args, **kwargs)
#     645             return future
#     646         else:
# --> 647             return sync(self.loop, func, *args, **kwargs)
#     648
#     649     def __repr__(self):
#
# /opt/conda/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, *args, **kwargs)
#     273     else:
#     274         while not e.is_set():
# --> 275             e.wait(10)
#     276     if error[0]:
#     277         six.reraise(*error[0])
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# /opt/conda/lib/python3.6/threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# Sort the countries by weighted goldstein scale
_ = len(df_by_country)
print(f"> {_} locations in the dataset")
to_sort = 'GoldsteinScale'
df_sorted = df_by_country.sort_values(by=to_sort, ascending=False).reset_index(drop=False)
print(f"> Sorted according to {to_sort} and reset index")

# top 10 and bottom 10 countries
top = df_sorted.iloc[:10, :]
bottom = df_sorted.iloc[-10:, :]

# Philippine value
ph = df_sorted[df_sorted.Actor1Geo_CountryCode == 'RP']
print("> loaded Philippines value")

# load country codes dictionary
country_codes = dict(pd.read_csv('fips.csv', index_col='Code').T)
country_names_top = [country_codes[i].values[0] for i in top.Actor1Geo_CountryCode]
country_names_bottom = [country_codes[i].values[0] for i in bottom.Actor1Geo_CountryCode]

# plot top countries
plt.barh('Global Average', world[to_sort])
plt.barh('Philippines', ph[to_sort])
plt.barh(country_names_top, top[to_sort])
plt.barh(country_names_bottom, bottom[to_sort])
plt.yticks(rotation=0)
plt.xlabel('Average Goldstein Scale')
plt.ylabel("Country Code")
plt.title('Countries with Lowest and Highest Goldstein Scale')
# Out:
# > 251 locations in the dataset
# > Sorted according to GoldsteinScale and reset index
# > loaded Philippines value
# Text(0.5,1,'Countries with Lowest and Highest Goldstein Scale')

# %%
# Sort the countries by weighted goldstein scale
_ = len(df_by_country)
print(f"> {_} locations in the dataset")
to_sort = 'weighted_goldstein'
df_sorted = df_by_country.sort_values(by=to_sort, ascending=False).reset_index(drop=False)
print(f"> Sorted according to {to_sort}")

# top 10 and bottom 10 countries
top = df_sorted.iloc[:10, :]
bottom = df_sorted.iloc[-10:, :]

# Philippine value
ph = df_sorted[df_sorted.Actor1Geo_CountryCode == 'RP']
print("> loaded Philippines value")

# load country codes dictionary
country_codes = dict(pd.read_csv('fips.csv', index_col='Code').T)
country_names_top = [country_codes[i].values[0] for i in top.Actor1Geo_CountryCode]
country_names_bottom = [country_codes[i].values[0] for i in bottom.Actor1Geo_CountryCode]

# plot top countries
plt.barh('Global Average', world[to_sort])
plt.barh('Philippines', ph[to_sort])
plt.barh(country_names_top, top[to_sort])
plt.barh(country_names_bottom, bottom[to_sort])
plt.yticks(rotation=0)
plt.xlabel('Average Goldstein Scale X Number of Mentions')
plt.ylabel("Country Code")
plt.title('Countries with Lowest and Highest Goldstein Scale X Number of Mentions')
# Out:
# > 251 locations in the dataset
# > Sorted according to weighted_goldstein
# > loaded Philippines value
# Text(0.5,1,'Countries with Lowest and Highest Goldstein Scale X Number of Mentions')

# %%
# Sort the countries by avg tone
_ = len(df_by_country)
print(f"> {_} locations in the dataset")
to_sort = 'AvgTone'
df_sorted = df_by_country.sort_values(by=to_sort, ascending=False).reset_index(drop=False)
print(f"> Sorted according to {to_sort}")

# top 10 and bottom 10 countries
top = df_sorted.iloc[:10, :]
bottom = df_sorted.iloc[-10:, :]

# Philippine value
ph = df_sorted[df_sorted.Actor1Geo_CountryCode == 'RP']
print("> loaded Philippines value")

# load country codes dictionary
country_codes = dict(pd.read_csv('fips.csv', index_col='Code').T)
country_names_top = [country_codes[i].values[0] for i in top.Actor1Geo_CountryCode]
country_names_bottom = [country_codes[i].values[0] for i in bottom.Actor1Geo_CountryCode]

# plot top countries
plt.barh('Global Average', world[to_sort])
plt.barh('Philippines', ph[to_sort])
plt.barh(country_names_top, top[to_sort])
plt.barh(country_names_bottom, bottom[to_sort])
plt.yticks(rotation=0)
plt.xlabel('Average Tone')
plt.ylabel("Country Code")
plt.title('Countries with Lowest and Highest Average Tone')
# Out:
# > 251 locations in the dataset
# > Sorted according to AvgTone
# > loaded Philippines value
# Text(0.5,1,'Countries with Lowest and Highest Average Tone')

# %%
# Sort the countries by weighted avg tone
_ = len(df_by_country)
print(f"> {_} locations in the dataset")
to_sort = 'weighted_avgtone'
df_sorted = df_by_country.sort_values(by=to_sort, ascending=False).reset_index(drop=False)
print(f"> Sorted according to {to_sort}")

# top 10 and bottom 10 countries
top = df_sorted.iloc[:10, :]
bottom = df_sorted.iloc[-10:, :]

# Philippine value
ph = df_sorted[df_sorted.Actor1Geo_CountryCode == 'RP']
print("> loaded Philippines value")

# load country codes dictionary
country_codes = dict(pd.read_csv('fips.csv', index_col='Code').T)
country_names_top = [country_codes[i].values[0] for i in top.Actor1Geo_CountryCode]
country_names_bottom = [country_codes[i].values[0] for i in bottom.Actor1Geo_CountryCode]

# plot top countries
plt.barh('Global Average', world[to_sort])
plt.barh('Philippines', ph[to_sort])
plt.barh(country_names_top, top[to_sort])
plt.barh(country_names_bottom, bottom[to_sort])
plt.yticks(rotation=0)
plt.xlabel('Average Tone X Number of Mentions')
plt.ylabel("Country Code")
plt.title('Countries with Lowest and Highest Average Tone X Number of Mentions')
# Out:
# > 251 locations in the dataset
# > Sorted according to weighted_avgtone
# > loaded Philippines value
# Text(0.5,1,'Countries with Lowest and Highest Average Tone X Number of Mentions')

# %%
# box plot?

# %%
# Goldstein Chloropleth
# import plotly.plotly as py
# import plotly.figure_factory as ff

# %%
# MAKE NEW ENVIRONMENT WITH GEOPANDAS

# %%
# PHILIPPINE CONTEXT

# %%
# f_events = glob.glob('/mnt/data/public/gdeltv2/201801*.export.CSV.zip')
# df_ = load_events(f_events)

# Filter Philippines dataframe
df_ph = df_[df_.Actor1Geo_CountryCode == 'RP']
print("> Selected Philippines")

# %%
# Open data from file for plotting
# Out:
# > Coordinates and other valuable data to be visualized pesisted successfully.

# %%
# Goldstein values vs Latitude and Longitude
# Color is goldstein while size is importance (num_mentions)
plt.style.use('default')
f, ax = plt.subplots(figsize=(8,8))
ax.scatter(x2, y2, c=goldstein2, marker='o', s=num_mentions2/2, cmap='Spectral', alpha=0.75)
plt.axis('equal')
# Out:
# (116.41466639131029, 127.05233360868971, 4.086345619934665, 21.924748167758214)

# %%
# AvgTone values vs Latitude and Longitude
# Color is goldstein while size is importance (num_mentions)
f, ax = plt.subplots(figsize=(8,8))
ax.scatter(x2, y2, c=avgtone2, marker='o', s=num_mentions2/2, cmap='Spectral', alpha=0.75)
plt.axis('equal')
# Out:
# (116.41466639131029, 127.05233360868971, 4.086345619934665, 21.924748167758214)

# %%
# Out:
#                       Day  GoldsteinScale  NumMentions  NumSources  \
# GlobalEventID
# 719025269      20180101.0             5.0         10.0         1.0
# 719025440      20180101.0            -5.0          4.0         1.0
# 719025441      20180101.0            -2.0          2.0         1.0
# 719025442      20180101.0            -2.0          2.0         1.0
# 719025881      20180101.0             3.0          1.0         1.0
#
#                NumArticles   AvgTone  Actor1Geo_Lat  Actor1Geo_Long  \
# GlobalEventID
# 719025269             10.0  1.972387       14.47780         120.893
# 719025440              4.0 -5.485893       14.58320         121.041
# 719025441              2.0 -5.485893        7.22361         124.246
# 719025442              2.0 -5.485893       14.60420         120.982
# 719025881              1.0 -0.904977        7.07306         125.613
#
#               Actor1Geo_CountryCode                     Actor1Geo_Fullname
# GlobalEventID
# 719025269                        RP       Cavite, Cavite City, Philippines
# 719025440                        RP  Mandaluyong, Mandaluyong, Philippines
# 719025441                        RP        Cotabato, Cotabato, Philippines
# 719025442                        RP            Manila, Manila, Philippines
# 719025881                        RP         Davao, Davao City, Philippines

# %%
# Out:
#   <div class="bk-root" id="9a1300ce-2e0c-4e79-8c29-3e3341ab2e16"></div>
